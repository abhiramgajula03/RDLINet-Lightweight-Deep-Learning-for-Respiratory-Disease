# %% [markdown]
# # Respiratory Disease Classification — D1 + D2 + D3 → Combined Dataset
# **Pipeline:** Audio → Mel Spectrogram → **Merge D1, D2 & D3** → Augmentation → RDLINet → 5-Fold CV
#
# | Dataset | Original Classes | Snippets |
# |---------|-----------------|----------|
# | D1 (ICBHI) | Bronchiectasis, Bronchiolitis, COPD, Healthy, Pneumonia, URTI | preprocessed separately |
# | D2 | Asthma, COPD, Healthy, Pneumonia | preprocessed separately |
# | D3 | *(your D3 classes here)* | preprocessed separately |
#
# **Unified class set:** Asthma, Bronchiectasis, Bronchiolitis, COPD, Healthy, Pneumonia, URTI *(plus any D3-exclusive classes)*
#
# > Overlapping classes (COPD, Healthy, Pneumonia) are **merged** — snippets from D1, D2, and D3 are pooled into the same class index.

# %%
# ── Cell 1 : Mount Google Drive ─────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Cell 2 : Paths & Directories ────────────────────────────────────────────
import os

# ---- D1 (ICBHI) ----
AUDIO_PATH_D1  = '/content/drive/MyDrive/Task 1/D1/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files'
LABELED_CSV_D1 = '/content/drive/MyDrive/Task 1/D1/Respiratory_Sound_Database/Respiratory_Sound_Database/labeled_files.csv'
PROCESSED_D1   = '/content/drive/MyDrive/Task2_Processed'

# ---- D2 ----
AUDIO_PATH_D2  = '/content/drive/MyDrive/Task 1/D2/audio_files'
LABELED_CSV_D2 = '/content/drive/MyDrive/Task 1/D2/d2_labeled.csv'
PROCESSED_D2   = '/content/drive/MyDrive/D2_Processed'

# ---- D3 ----
AUDIO_PATH_D3  = '/content/drive/MyDrive/Task 1/D3/RespiratoryDatabase@TR'
LABELED_CSV_D3 = '/content/drive/MyDrive/Task 1/D3/final_ml_dataset3.csv'
PROCESSED_D3   = '/content/drive/MyDrive/D3_Processed'
# ---- Combined output ----
PROCESSED_COMBINED   = '/content/drive/MyDrive/Combined_Processed'
RESULTS_DIR_COMBINED = '/content/drive/MyDrive/Combined_Results'

for d in [PROCESSED_D1, PROCESSED_D2, PROCESSED_D3, PROCESSED_COMBINED, RESULTS_DIR_COMBINED]:
    os.makedirs(d, exist_ok=True)

print('D1 audio exists :', os.path.exists(AUDIO_PATH_D1))
print('D1 CSV   exists :', os.path.exists(LABELED_CSV_D1))
print('D2 audio exists :', os.path.exists(AUDIO_PATH_D2))
print('D2 CSV   exists :', os.path.exists(LABELED_CSV_D2))
print('D3 audio exists :', os.path.exists(AUDIO_PATH_D3))
print('D3 CSV   exists :', os.path.exists(LABELED_CSV_D3))
# Out:
# D1 audio exists : True
# D1 CSV   exists : True
# D2 audio exists : True
# D2 CSV   exists : True
# D3 audio exists : True
# D3 CSV   exists : True

# %%
# ── Cell 3 : Imports ─────────────────────────────────────────────────────────
import gc
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import librosa
import cv2
from tqdm import tqdm

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, DepthwiseConv2D, BatchNormalization,
    LeakyReLU, MaxPool2D, GlobalAveragePooling2D,
    Dropout, Dense, Multiply, Concatenate
)
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    confusion_matrix, accuracy_score, classification_report
)

print('TF version :', tf.__version__)
print('Librosa    :', librosa.__version__)
# Out:
# TF version : 2.20.0
# Librosa    : 0.11.0

# %% [markdown]
# ---
# ## Shared Utilities

# %%
# ── Cell 4 : Audio → Mel-Spectrogram Image ───────────────────────────────────
def process_audio_to_images(wav_path, sr_target=4000):
    """
    Paper pipeline (Section III-A / III-C):
      1. Resample to 4 kHz
      2. 5-sec snippets with 50 % overlap
      3. DFT baseline-wander removal (0-1 Hz zeroed)
      4. Amplitude normalisation to [-1, 1]
      5. Mel spectrogram: 64 filters, n_fft=1024, hop=512, Hamming window
      6. Log-scale → resize 64×38 → Jet colormap → float32 [0,1]
    """
    images = []
    try:
        signal, _ = librosa.load(wav_path, sr=sr_target, mono=True)
    except Exception as e:
        print(f'  Error loading {wav_path}: {e}')
        return images

    win = 5 * sr_target
    hop = win // 2

    for start in range(0, len(signal) - win + 1, hop):
        snippet = signal[start : start + win].copy()

        # DFT baseline-wander removal
        N       = len(snippet)
        fft_val = np.fft.fft(snippet)
        freqs   = np.fft.fftfreq(N, 1.0 / sr_target)
        fft_val[np.abs(freqs) <= 1.0] = 0
        snippet = np.real(np.fft.ifft(fft_val))

        # Amplitude normalisation
        max_val = np.max(np.abs(snippet))
        if max_val > 0:
            snippet = snippet / max_val

        # Mel spectrogram
        mel    = librosa.feature.melspectrogram(
            y=snippet, sr=sr_target,
            n_fft=1024, hop_length=512,
            n_mels=64, window='hamming'
        )
        mel_db = librosa.power_to_db(mel, ref=np.max)

        # Resize → Jet colormap → float32
        mel_resized = cv2.resize(mel_db, (38, 64))
        mel_norm    = cv2.normalize(
            mel_resized, None, 0, 255, cv2.NORM_MINMAX
        ).astype(np.uint8)
        mel_jet = cv2.applyColorMap(mel_norm, cv2.COLORMAP_JET)
        mel_rgb = cv2.cvtColor(mel_jet, cv2.COLOR_BGR2RGB)
        images.append(mel_rgb.astype('float32') / 255.0)

    return images

print('process_audio_to_images defined')
# Out:
# process_audio_to_images defined

# %%
# ── Cell 5 : Augmentation Function ───────────────────────────────────────────
def augment_spectrogram(img):
    """
    Returns 10 augmented versions of one spectrogram image (H×W×C float32).

    Techniques applied
    ------------------
    1. Time-stretch  ×4  (factors 0.8 / 0.9 / 1.1 / 1.2)  — linear interp
    2. Additive noise ×3  (std 0.03 / 0.06 / 0.10)
    3. Frequency masking ×1  (random 16-row band zeroed)
    4. Time masking     ×1  (random 10-column band zeroed)
    5. Brightness shift ×1  (random scale in [0.85, 1.15])
    """
    aug     = []
    H, W, C = img.shape

    # ---- 1. Time-stretch ----
    for factor in [0.8, 0.9, 1.1, 1.2]:
        stretched = np.zeros((H, W, C), dtype='float32')
        new_len   = max(1, int(W * factor))
        x_new     = np.linspace(0, W - 1, new_len)
        x_old     = np.arange(W)
        for c in range(C):
            for row in range(H):
                interped = np.interp(x_new, x_old, img[row, :, c])
                if new_len < W:
                    interped = np.pad(interped, (0, W - new_len), mode='edge')
                else:
                    interped = interped[:W]
                stretched[row, :, c] = interped
        aug.append(stretched)

    # ---- 2. Additive Gaussian noise ----
    for noise_std in [0.03, 0.06, 0.10]:
        noisy = img + np.random.normal(0, noise_std, img.shape).astype('float32')
        aug.append(np.clip(noisy, 0.0, 1.0))

    # ---- 3. Frequency masking ----
    f_masked         = img.copy()
    f_start          = np.random.randint(0, H - 16)
    f_masked[f_start:f_start + 16, :, :] = 0
    aug.append(f_masked)

    # ---- 4. Time masking ----
    t_masked         = img.copy()
    t_start          = np.random.randint(0, W - 10)
    t_masked[:, t_start:t_start + 10, :] = 0
    aug.append(t_masked)

    # ---- 5. Brightness shift ----
    aug.append(
        np.clip(img * np.random.uniform(0.85, 1.15), 0.0, 1.0).astype('float32')
    )

    return aug   # 10 augmented images


def balance_dataset(X, Y, y_labels, class_list, target_count):
    """
    Augments minority classes until every class has `target_count` samples.
    Returns (X_balanced, Y_balanced, y_labels_balanced).
    """
    X_aug_list = [X]
    Y_aug_list = [Y]

    for cls_idx in range(len(class_list)):
        current = int((y_labels == cls_idx).sum())
        if current >= target_count:
            print(f'  Class {cls_idx} ({class_list[cls_idx]:22s}): {current:5d} — already >= target, skipping')
            continue

        X_min  = X[y_labels == cls_idx]
        Y_min  = Y[y_labels == cls_idx]
        needed = target_count - current
        added  = 0
        i      = 0

        while added < needed:
            for aug_img in augment_spectrogram(X_min[i % len(X_min)]):
                if added >= needed:
                    break
                X_aug_list.append(aug_img[np.newaxis])
                Y_aug_list.append(Y_min[i % len(Y_min)][np.newaxis])
                added += 1
            i += 1

        print(f'  Class {cls_idx} ({class_list[cls_idx]:22s}): {current:5d} -> {current + added}')

    X_bal = np.concatenate(X_aug_list, axis=0)
    Y_bal = np.concatenate(Y_aug_list, axis=0)
    y_bal = np.argmax(Y_bal, axis=1)
    return X_bal, Y_bal, y_bal

print('augment_spectrogram & balance_dataset defined')
# Out:
# augment_spectrogram & balance_dataset defined

# %%
# ── Cell 6 : RDLINet Architecture ────────────────────────────────────────────
def RDLINet(dim, output_neurons, output_activation):
    """
    Residual Depthwise-separable Lightweight Inception Network.
    Each inception block fuses 1x1, DW3x3+PW, DW5x5+PW, MaxPool+PW branches.
    A GLU-like Dense gate head controls the final projection.
    """

    def inception_block(x, filters, reps):
        for _ in range(reps):
            t1 = Conv2D(filters[0], (1, 1), padding='same')(x)
            t1 = BatchNormalization()(t1)
            t1 = LeakyReLU()(t1)

            t2 = DepthwiseConv2D((3, 3), padding='same')(x)
            t2 = BatchNormalization()(t2)
            t2 = LeakyReLU()(t2)
            t2 = Conv2D(filters[1], (1, 1), padding='same')(t2)
            t2 = BatchNormalization()(t2)
            t2 = LeakyReLU()(t2)

            t3 = DepthwiseConv2D((5, 5), padding='same')(x)
            t3 = BatchNormalization()(t3)
            t3 = LeakyReLU()(t3)
            t3 = Conv2D(filters[2], (1, 1), padding='same')(t3)
            t3 = BatchNormalization()(t3)
            t3 = LeakyReLU()(t3)

            t4 = MaxPool2D((3, 3), strides=1, padding='same')(x)
            t4 = Conv2D(filters[3], (1, 1), padding='same')(t4)
            t4 = BatchNormalization()(t4)
            t4 = LeakyReLU()(t4)

            x = Concatenate()([t1, t2, t3, t4])
        return x

    k           = 32
    input_layer = Input(shape=dim)

    x = Conv2D(k, (3, 3), strides=2, padding='same')(input_layer)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPool2D((3, 3), strides=2, padding='same')(x)

    x = DepthwiseConv2D((3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = Conv2D(2 * k, (1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPool2D((2, 2))(x)

    x = inception_block(x, [k, k, k, k], 2)
    x = MaxPool2D((2, 2))(x)

    x  = GlobalAveragePooling2D()(x)
    x  = Dropout(0.3)(x)
    g  = Dense(15, activation='sigmoid')(x)
    v  = Dense(15, activation='linear')(x)
    gv = Multiply()([g, v])

    output = Dense(output_neurons, activation=output_activation)(gv)
    return Model(input_layer, output, name='RDLINet')

print('RDLINet defined')
tmp = RDLINet((64, 38, 3), 7, 'softmax')
tmp.summary()
del tmp
# Out:
# RDLINet defined
# Model: "RDLINet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 38, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 19,    │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 19,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 32, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 10,    │          0 │ leaky_re_lu[0][0] │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 16, 10,    │        320 │ max_pooling2d[0]… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 10,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 16, 10,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 10,    │      2,112 │ leaky_re_lu_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 10,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 16, 10,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 8, 5, 64)  │          0 │ leaky_re_lu_2[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 8, 5, 64)  │        640 │ max_pooling2d_1[… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 8, 5, 64)  │      1,664 │ max_pooling2d_1[… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 64)  │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 64)  │        256 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 8, 5, 64)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 8, 5, 64)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 8, 5, 64)  │          0 │ max_pooling2d_1[… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 5, 32)  │      2,080 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 8, 5, 32)  │      2,080 │ leaky_re_lu_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 8, 5, 32)  │      2,080 │ leaky_re_lu_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 8, 5, 32)  │      2,080 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 5, 128) │          0 │ leaky_re_lu_3[0]… │
# │ (Concatenate)       │                   │            │ leaky_re_lu_5[0]… │
# │                     │                   │            │ leaky_re_lu_7[0]… │
# │                     │                   │            │ leaky_re_lu_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 8, 5, 128) │      1,280 │ concatenate[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 8, 5, 128) │      3,328 │ concatenate[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 128) │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 128) │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 8, 5, 128) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 8, 5, 128) │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 5, 128) │          0 │ concatenate[0][0] │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 5, 32)  │      4,128 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 5, 32)  │      4,128 │ leaky_re_lu_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 5, 32)  │      4,128 │ leaky_re_lu_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 5, 32)  │      4,128 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 5, 32)  │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 8, 5, 32)  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 8, 5, 128) │          0 │ leaky_re_lu_9[0]… │
# │ (Concatenate)       │                   │            │ leaky_re_lu_11[0… │
# │                     │                   │            │ leaky_re_lu_13[0… │
# │                     │                   │            │ leaky_re_lu_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 4, 2, 128) │          0 │ concatenate_1[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_4[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 15)        │      1,935 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 15)        │      1,935 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 15)        │          0 │ dense[0][0],      │
# │                     │                   │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 7)         │        112 │ multiply[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 42,126 (164.55 KB)
#  Trainable params: 40,590 (158.55 KB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
# ── Cell 7 : Training Helper ─────────────────────────────────────────────────
def run_kfold_training(
    X, Y, y_labels, class_list, results_dir, tag,
    n_splits=5, epochs=300, batch_size=128, lr=0.008
):
    H, W, C    = X.shape[1], X.shape[2], X.shape[3]
    n_classes  = len(class_list)
    kf         = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    acc_scores = []

    print(f'Input shape   : ({H}, {W}, {C})')
    print(f'Classes ({n_classes})  : {class_list}')
    print(f'Total samples : {len(X)}')

    for fold, (train_idx, test_idx) in enumerate(kf.split(X, y_labels), start=1):
        print(f'\n{"="*44}')
        print(f'  FOLD {fold} / {n_splits}  [{tag}]')
        print(f'{"="*44}')

        tf.keras.backend.clear_session()
        gc.collect()

        X_train, X_test = X[train_idx], X[test_idx]
        Y_train, Y_test = Y[train_idx], Y[test_idx]

        model = RDLINet((H, W, C), n_classes, 'softmax')
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss', patience=15,
                restore_best_weights=True
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss', factor=0.5,
                patience=8, min_lr=1e-6, verbose=1
            )
        ]

        history = model.fit(
            X_train, Y_train,
            validation_data=(X_test, Y_test),
            epochs=epochs, batch_size=batch_size,
            callbacks=callbacks, verbose=1
        )

        # ── Predictions & Metrics ─────────────────────────────────────────────
        preds  = model.predict(X_test, verbose=0)
        y_pred = np.argmax(preds, axis=1)
        y_true = np.argmax(Y_test, axis=1)
        acc    = accuracy_score(y_true, y_pred)
        acc_scores.append(acc)

        print(f'\nFold {fold} Accuracy : {acc * 100:.4f}%')
        print(classification_report(y_true, y_pred,
                                    target_names=class_list, zero_division=0))

        # ── Confusion Matrix Data ─────────────────────────────────────────────
        cm         = confusion_matrix(y_true, y_pred)
        cm_percent = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis] + 1e-9)

        # ── Combined Figure ───────────────────────────────────────────────────
        fig = plt.figure(figsize=(15, 4.5))
        fig.patch.set_facecolor('white')

        # ── Plot 1 : Accuracy ─────────────────────────────────────────────────
        ax1 = fig.add_subplot(1, 3, 1)
        ax1.plot(history.history['accuracy'],     color='#00C853', linewidth=2, label='Train')
        ax1.plot(history.history['val_accuracy'], color='#D500F9', linewidth=2, label='Test')
        ax1.set_title('Model Accuracy', fontweight='bold')
        ax1.set_xlabel('No of Epochs')
        ax1.set_ylabel('Accuracy')
        ax1.legend()
        ax1.grid(True, linestyle='--', alpha=0.6)
        ax1.set_facecolor('white')

        # ── Plot 2 : Loss ─────────────────────────────────────────────────────
        ax2 = fig.add_subplot(1, 3, 2)
        ax2.plot(history.history['loss'],     color='#00C853', linewidth=2, label='Train')
        ax2.plot(history.history['val_loss'], color='#D500F9', linewidth=2, label='Test')
        ax2.set_title('Model Loss', fontweight='bold')
        ax2.set_xlabel('No of Epochs')
        ax2.set_ylabel('Loss')
        ax2.legend()
        ax2.grid(True, linestyle='--', alpha=0.6)
        ax2.set_facecolor('white')

        # ── Plot 3 : Confusion Matrix ─────────────────────────────────────────
        ax3 = fig.add_subplot(1, 3, 3)
        sns.heatmap(
         cm_percent, annot=True, fmt='.2f', cmap='YlOrRd',
         xticklabels=class_list, yticklabels=class_list,
         ax=ax3, linewidths=0.5, linecolor='white',
         vmin=0.0, vmax=1.0
        )
        ax3.set_title(f'RDLINet')
        ax3.set_xlabel('Predicted Labels', fontsize=10)
        ax3.set_ylabel('True Labels',      fontsize=10)
        ax3.set_xticklabels(class_list, rotation=45, ha='right',
                            fontsize=9, fontweight='bold', color='#111111')
        ax3.set_yticklabels(class_list, rotation=0,
                            fontsize=9, fontweight='bold', color='#111111')

        plt.tight_layout()
        plt.savefig(f'{results_dir}/{tag}_fold{fold}_combined.png', dpi=150, bbox_inches='tight')
        plt.show()

        # ── Save Weights ──────────────────────────────────────────────────────
        model.save_weights(f'{results_dir}/{tag}_fold{fold}.weights.h5')
        print(f'Fold {fold} weights saved.')

    # ── Final Summary ─────────────────────────────────────────────────────────
    results = {
        'tag'             : tag,
        'classes'         : class_list,
        'fold_accuracies' : [float(s * 100) for s in acc_scores],
        'mean_accuracy'   : float(np.mean(acc_scores) * 100),
        'std_accuracy'    : float(np.std(acc_scores) * 100)
    }
    with open(f'{results_dir}/{tag}_results.json', 'w') as f:
        json.dump(results, f, indent=2)

    print(f'\n{"="*44}')
    print(f'FINAL RESULTS — {tag}')
    print(f'{"="*44}')
    for i, s in enumerate(acc_scores, 1):
        print(f'  Fold {i} : {s * 100:.4f}%')
    print(f'  Mean  : {np.mean(acc_scores) * 100:.4f}%')
    print(f'  Std   : {np.std(acc_scores) * 100:.4f}%')
    return acc_scores

print('run_kfold_training defined')
# Out:
# run_kfold_training defined

# %% [markdown]
# ---
# ## Part A — Preprocess D1 (ICBHI — 6 classes)
# Run Cells 8-9 once, then use Cell 10 to reload on future runs.

# %%
# ── Cell 8 : D1 — Load & Filter CSV ─────────────────────────────────────────
D1_CLASSES = [
    'Bronchiectasis', 'Bronchiolitis', 'COPD',
    'Healthy', 'Pneumonia', 'URTI'
]

df_d1 = pd.read_csv(LABELED_CSV_D1)
df_d1 = df_d1[
    df_d1['filename'].str.endswith('.wav') &
    df_d1['diagnosis'].isin(D1_CLASSES)
].reset_index(drop=True)

print(f'D1 wav files : {len(df_d1)}')
print(df_d1['diagnosis'].value_counts())
# Out:
# D1 wav files : 917
# diagnosis
# COPD              793
# Pneumonia          37
# Healthy            35
# URTI               23
# Bronchiectasis     16
# Bronchiolitis      13
# Name: count, dtype: int64

# %%
# ── Cell 9 : D1 — Extract Mel-Spectrogram Images & Save ──────────────────────
# Run ONCE — skip on future runs (use Cell 10 instead)
X_d1_list, y_d1_list, skipped = [], [], 0

for _, row in tqdm(df_d1.iterrows(), total=len(df_d1), desc='D1 Audio'):
    wav_path = os.path.join(AUDIO_PATH_D1, row['filename'])
    if not os.path.exists(wav_path):
        skipped += 1
        continue
    for img in process_audio_to_images(wav_path):
        X_d1_list.append(img)
        y_d1_list.append(row['diagnosis'])

print(f'Skipped  : {skipped}')
print(f'Snippets : {len(X_d1_list)}')

X_d1     = np.array(X_d1_list, dtype='float32')
y_d1_raw = np.array(y_d1_list)

# Save with RAW string labels so merging is label-safe
np.save(f'{PROCESSED_D1}/X_d1.npy',        X_d1)
np.save(f'{PROCESSED_D1}/y_raw_d1.npy',    y_d1_raw)
print('D1 arrays saved.')

# Preview
unique, counts = np.unique(y_d1_raw, return_counts=True)
for u, c in zip(unique, counts):
    print(f'  {u:22s}: {c}')
# Out:
# D1 Audio: 100%|██████████| 917/917 [16:25<00:00,  1.08s/it]
# Skipped  : 0
# Snippets : 6916
# D1 arrays saved.
#   Bronchiectasis        : 112
#   Bronchiolitis         : 91
#   COPD                  : 6055
#   Healthy               : 240
#   Pneumonia             : 259
#   URTI                  : 159

# %%
# ── Cell 10 : D1 — Reload (future runs) ──────────────────────────────────────
X_d1     = np.load(f'{PROCESSED_D1}/X_d1.npy')
y_d1_raw = np.load(f'{PROCESSED_D1}/y_raw_d1.npy', allow_pickle=True)

print('D1 reloaded — X:', X_d1.shape)
unique, counts = np.unique(y_d1_raw, return_counts=True)
for u, c in zip(unique, counts):
    print(f'  {u}: {c}')
# Out:
# D1 reloaded — X: (6916, 64, 38, 3)
#   Bronchiectasis: 112
#   Bronchiolitis: 91
#   COPD: 6055
#   Healthy: 240
#   Pneumonia: 259
#   URTI: 159

# %% [markdown]
# ---
# ## Part B — Preprocess D2 (4 classes)
# Run Cells 11-12 once, then use Cell 13 to reload on future runs.

# %%
# ── Cell 11 : D2 — Load CSV ──────────────────────────────────────────────────
D2_CLASSES = ['Asthma', 'COPD', 'Healthy', 'Pneumonia']

df_d2 = pd.read_csv(LABELED_CSV_D2)
df_d2 = df_d2[
    df_d2['filename'].str.endswith('.wav')
].reset_index(drop=True)

print(f'D2 wav files : {len(df_d2)}')
print(df_d2['diagnosis'].value_counts())
# Out:
# D2 wav files : 252
# diagnosis
# Healthy      105
# Asthma        99
# COPD          33
# Pneumonia     15
# Name: count, dtype: int64

# %%
# ── Cell 12 : D2 — Extract Mel-Spectrogram Images & Save ──────────────────────
# Run ONCE — skip on future runs (use Cell 13 instead)
X_d2_list, y_d2_list, skipped = [], [], 0

for _, row in tqdm(df_d2.iterrows(), total=len(df_d2), desc='D2 Audio'):
    wav_path = os.path.join(AUDIO_PATH_D2, row['filename'])
    if not os.path.exists(wav_path):
        skipped += 1
        continue
    for img in process_audio_to_images(wav_path):
        X_d2_list.append(img)
        y_d2_list.append(row['diagnosis'])

print(f'Skipped  : {skipped}')
print(f'Snippets : {len(X_d2_list)}')

X_d2     = np.array(X_d2_list, dtype='float32')
y_d2_raw = np.array(y_d2_list)

np.save(f'{PROCESSED_D2}/X_d2.npy',     X_d2)
np.save(f'{PROCESSED_D2}/y_raw_d2.npy', y_d2_raw)
print('D2 arrays saved.')

unique, counts = np.unique(y_d2_raw, return_counts=True)
for u, c in zip(unique, counts):
    print(f'  {u:22s}: {c}')
# Out:
# D2 Audio: 100%|██████████| 252/252 [04:30<00:00,  1.07s/it]
# Skipped  : 0
# Snippets : 1419
# D2 arrays saved.
#   Asthma                : 531
#   COPD                  : 204
#   Healthy               : 588
#   Pneumonia             : 96

# %%
# ── Cell 13 : D2 — Reload (future runs) ──────────────────────────────────────
X_d2     = np.load(f'{PROCESSED_D2}/X_d2.npy')
y_d2_raw = np.load(f'{PROCESSED_D2}/y_raw_d2.npy', allow_pickle=True)

print('D2 reloaded — X:', X_d2.shape)
unique, counts = np.unique(y_d2_raw, return_counts=True)
for u, c in zip(unique, counts):
    print(f'  {u}: {c}')
# Out:
# D2 reloaded — X: (1419, 64, 38, 3)
#   Asthma: 531
#   COPD: 204
#   Healthy: 588
#   Pneumonia: 96

# %% [markdown]
# ---
# ## Part C — Preprocess D3
# Run Cells 14-15 once, then use Cell 16 to reload on future runs.

# %%
# ── Cell 14 : D3 — Load CSV ──────────────────────────────────────────────────
# Update D3_CLASSES to match the actual classes in your D3 dataset
D3_CLASSES = ['Asthma', 'COPD', 'Healthy', 'Pneumonia']  # <-- edit as needed

df_d3 = pd.read_csv(LABELED_CSV_D3)
df_d3 = df_d3[
    df_d3['file_name'].str.endswith('.wav')
].reset_index(drop=True)

print(f'D3 wav files : {len(df_d3)}')
print(df_d3['label'].value_counts())
# Out:
# D3 wav files : 504
# label
# COPD    504
# Name: count, dtype: int64

# %%
# ── Cell 15 : D3 — Extract Mel-Spectrogram Images & Save ─────────────────────
# Run ONCE — skip on future runs (use Cell 16 instead)
X_d3_list, y_d3_list, skipped = [], [], 0

for _, row in tqdm(df_d3.iterrows(), total=len(df_d3), desc='D3 Audio'):
    wav_path = os.path.join(AUDIO_PATH_D3, row['file_name'])
    if not os.path.exists(wav_path):
        skipped += 1
        continue
    for img in process_audio_to_images(wav_path):
        X_d3_list.append(img)
        y_d3_list.append(row['label'])

print(f'Skipped  : {skipped}')
print(f'Snippets : {len(X_d3_list)}')

X_d3     = np.array(X_d3_list, dtype='float32')
y_d3_raw = np.array(y_d3_list)

np.save(f'{PROCESSED_D3}/X_d3.npy',     X_d3)
np.save(f'{PROCESSED_D3}/y_raw_d3.npy', y_d3_raw)
print('D3 arrays saved.')

unique, counts = np.unique(y_d3_raw, return_counts=True)
for u, c in zip(unique, counts):
    print(f'  {u:22s}: {c}')
# Out:
# D3 Audio: 100%|██████████| 504/504 [08:31<00:00,  1.02s/it]
# Skipped  : 0
# Snippets : 3629
# D3 arrays saved.
#   COPD                  : 3629

# %%
# ── Cell 16 : D3 — Reload (future runs) ──────────────────────────────────────
X_d3     = np.load(f'{PROCESSED_D3}/X_d3.npy')
y_d3_raw = np.load(f'{PROCESSED_D3}/y_raw_d3.npy', allow_pickle=True)

print('D3 reloaded — X:', X_d3.shape)
unique, counts = np.unique(y_d3_raw, return_counts=True)
for u, c in zip(unique, counts):
    print(f'  {u}: {c}')
# Out:
# D3 reloaded — X: (3629, 64, 38, 3)
#   COPD: 3629

# %% [markdown]
# ---
# ## Part D — Merge D1 + D2 + D3 into a Single Dataset
#
# **Unified class set:** sorted union of all three datasets' classes.
#
# Overlapping classes (e.g. COPD, Healthy, Pneumonia) pool snippets from all three datasets under the same label.

# %%
def clean_label(label):
    label = str(label).strip()
    label = label.upper()
    label = re.sub(r'\d+', '', label)

    mapping_fix = {
        'COPD': 'COPD',
        'ASTHMA': 'Asthma',
        'HEALTHY': 'Healthy',
        'PNEUMONIA': 'Pneumonia',
        'URTI': 'URTI',
        'BRONCHIECTASIS': 'Bronchiectasis',
        'BRONCHIOLITIS': 'Bronchiolitis'
    }

    return mapping_fix.get(label, label)

# %%
# ── Cell 17 : Merge D1 + D2 + D3 into one unified dataset ───────────────────

# Unified class list — sorted alphabetically for reproducibility
COMBINED_CLASSES = sorted(set(D1_CLASSES) | set(D2_CLASSES) | set(D3_CLASSES))
print('Unified classes:', COMBINED_CLASSES)

combined_lbl = {cls: idx for idx, cls in enumerate(COMBINED_CLASSES)}
print('Label map      :', combined_lbl)

# ---- Stack images ----
X_combined = np.concatenate([X_d1, X_d2, X_d3], axis=0)   # (N1+N2+N3, 64, 38, 3)

# ---- Map string labels → unified integer indices ----
y_combined_raw = np.concatenate([y_d1_raw, y_d2_raw, y_d3_raw], axis=0)
y_combined_lbl = np.array([combined_lbl[l] for l in y_combined_raw])

# ---- One-hot encode ----
n_combined = len(COMBINED_CLASSES)
Y_combined = np.eye(n_combined)[y_combined_lbl]

print(f'\nCombined X shape : {X_combined.shape}')
print(f'Combined Y shape : {Y_combined.shape}')
print('\nPer-class snippet counts (before augmentation):')
for idx, cls in enumerate(COMBINED_CLASSES):
    cnt = int((y_combined_lbl == idx).sum())
    src_parts = []
    if cls in D1_CLASSES: src_parts.append('D1')
    if cls in D2_CLASSES: src_parts.append('D2')
    if cls in D3_CLASSES: src_parts.append('D3')
    src = '(' + '+'.join(src_parts) + ')'
    print(f'  {idx}  {cls:22s} {src:12s}: {cnt:6d}')

# Optional: save the merged (pre-augmentation) arrays
np.save(f'{PROCESSED_COMBINED}/X_combined_raw.npy',     X_combined)
np.save(f'{PROCESSED_COMBINED}/Y_combined_raw.npy',     Y_combined)
np.save(f'{PROCESSED_COMBINED}/y_lbl_combined_raw.npy', y_combined_lbl)
print('\nMerged (pre-aug) arrays saved to Combined_Processed.')
# Out:
# Unified classes: ['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
# Label map      : {'Asthma': 0, 'Bronchiectasis': 1, 'Bronchiolitis': 2, 'COPD': 3, 'Healthy': 4, 'Pneumonia': 5, 'URTI': 6}
#
# Combined X shape : (11964, 64, 38, 3)
# Combined Y shape : (11964, 7)
#
# Per-class snippet counts (before augmentation):
#   0  Asthma                 (D2+D3)     :    531
#   1  Bronchiectasis         (D1)        :    112
#   2  Bronchiolitis          (D1)        :     91
#   3  COPD                   (D1+D2+D3)  :   9888
#   4  Healthy                (D1+D2+D3)  :    828
#   5  Pneumonia              (D1+D2+D3)  :    355
#   6  URTI                   (D1)        :    159
#
# Merged (pre-aug) arrays saved to Combined_Processed.

# %%
# ── Cell 17b : (Optional) Reload merged pre-aug arrays on future runs ────────
# X_combined     = np.load(f'{PROCESSED_COMBINED}/X_combined_raw.npy')
# Y_combined     = np.load(f'{PROCESSED_COMBINED}/Y_combined_raw.npy')
# y_combined_lbl = np.load(f'{PROCESSED_COMBINED}/y_lbl_combined_raw.npy')
# COMBINED_CLASSES = sorted(set(D1_CLASSES) | set(D2_CLASSES) | set(D3_CLASSES))
# print('Reloaded combined — X:', X_combined.shape)

# %% [markdown]
# ---
# ## Part E — Augment the Combined Dataset
# Every class in the unified class set is brought up to `target_count` using the 10-technique augmentation pipeline.

# %%
# ── Cell 15 : Augment Combined Dataset (target 6 000 per class) ───────────────
#
# Use 6 000 as the unified target. You can lower this if RAM is tight.
# All 7 classes will be balanced to exactly this count.

TARGET_PER_CLASS = 6000

print(f'Augmenting combined dataset to {TARGET_PER_CLASS} per class...')
X_aug, Y_aug, y_aug = balance_dataset(
    X_combined, Y_combined, y_combined_lbl,
    COMBINED_CLASSES,
    target_count=TARGET_PER_CLASS
)

print(f'\nFinal augmented shape : {X_aug.shape}')
print(f'Total samples         : {len(X_aug)}  ({len(COMBINED_CLASSES)} classes x {TARGET_PER_CLASS})')
print('\nPer-class counts after augmentation:')
for idx, cls in enumerate(COMBINED_CLASSES):
    print(f'  {idx}  {cls:22s}: {(y_aug == idx).sum()}')

# Save augmented combined dataset
np.save(f'{PROCESSED_COMBINED}/X_aug.npy',    X_aug)
np.save(f'{PROCESSED_COMBINED}/Y_aug.npy',    Y_aug)
np.save(f'{PROCESSED_COMBINED}/y_lbl_aug.npy', y_aug)
print('\nAugmented combined arrays saved.')
# Out:
# Augmenting combined dataset to 6000 per class...
#   Class 0 (Asthma                ):   531 -> 6000
#   Class 1 (Bronchiectasis        ):   112 -> 6000
#   Class 2 (Bronchiolitis         ):    91 -> 6000
#   Class 3 (COPD                  ):  9888 — already >= target, skipping
#   Class 4 (Healthy               ):   828 -> 6000
#   Class 5 (Pneumonia             ):   355 -> 6000
#   Class 6 (URTI                  ):   159 -> 6000
#
# Final augmented shape : (45888, 64, 38, 3)
# Total samples         : 45888  (7 classes x 6000)
#
# Per-class counts after augmentation:
#   0  Asthma                : 6000
#   1  Bronchiectasis        : 6000
#   2  Bronchiolitis         : 6000
#   3  COPD                  : 9888
#   4  Healthy               : 6000
#   5  Pneumonia             : 6000
#   6  URTI                  : 6000
#
# Augmented combined arrays saved.

# %%
# ── Cell 18b : (Optional) Reload augmented arrays on future runs ─────────────
# X_aug  = np.load(f'{PROCESSED_COMBINED}/X_aug.npy')
# Y_aug  = np.load(f'{PROCESSED_COMBINED}/Y_aug.npy')
# y_aug  = np.load(f'{PROCESSED_COMBINED}/y_lbl_aug.npy')
# COMBINED_CLASSES = sorted(set(D1_CLASSES) | set(D2_CLASSES) | set(D3_CLASSES))
# print('Reloaded augmented combined — X:', X_aug.shape)

# %% [markdown]
# ---
# ## Part F — Visualise Class Balance (Before vs After Augmentation)

# %%
# ── Cell 16 : Class distribution plot — before vs after augmentation ──────────
before_counts = [(y_combined_lbl == i).sum() for i in range(len(COMBINED_CLASSES))]
after_counts  = [(y_aug == i).sum()          for i in range(len(COMBINED_CLASSES))]

x = np.arange(len(COMBINED_CLASSES))
w = 0.35

fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(x - w/2, before_counts, w, label='Before augmentation', color='steelblue')
ax.bar(x + w/2, after_counts,  w, label='After augmentation',  color='darkorange')
ax.axhline(TARGET_PER_CLASS, color='red', linestyle='--', linewidth=1, label=f'Target ({TARGET_PER_CLASS})')
ax.set_xticks(x)
ax.set_xticklabels(COMBINED_CLASSES, rotation=20, ha='right')
ax.set_ylabel('Number of snippets')
ax.set_title('Combined Dataset (D1 + D2 + D3) — Class Balance Before vs After Augmentation')
ax.legend()
plt.tight_layout()
plt.savefig(f'{RESULTS_DIR_COMBINED}/class_balance.png', dpi=150)
plt.show()

# %% [markdown]
# ---
# ## Part G — RDLINet 5-Fold Training & Testing on Combined Dataset

# %%
# ── Cell 20 : Train RDLINet on D1 + D2 + D3 combined ────────────────────────
combined_scores = run_kfold_training(
    X_aug, Y_aug, y_aug,
    class_list  = COMBINED_CLASSES,
    results_dir = RESULTS_DIR_COMBINED,
    tag         = 'D1_D2_D3_Combined',
    n_splits    = 5,
    epochs      = 300,
    batch_size  = 128,
    lr          = 0.008
)
# Out:
# Input shape   : (64, 38, 3)
# Classes (7)  : ['Asthma', 'Bronchiectasis', 'Bronchiolitis', 'COPD', 'Healthy', 'Pneumonia', 'URTI']
# Total samples : 45888
#
# ============================================
#   FOLD 1 / 5  [D1_D2_D3_Combined]
# ============================================
# Epoch 1/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 58s 87ms/step - accuracy: 0.6865 - loss: 0.7970 - val_accuracy: 0.3893 - val_loss: 2.6573 - learning_rate: 0.0080
# Epoch 2/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8421 - loss: 0.4042 - val_accuracy: 0.2769 - val_loss: 10.6458 - learning_rate: 0.0080
# Epoch 3/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8792 - loss: 0.3066 - val_accuracy: 0.6708 - val_loss: 1.4923 - learning_rate: 0.0080
# Epoch 4/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9007 - loss: 0.2510 - val_accuracy: 0.5538 - val_loss: 2.5176 - learning_rate: 0.0080
# Epoch 5/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9145 - loss: 0.2160 - val_accuracy: 0.5236 - val_loss: 4.3184 - learning_rate: 0.0080
# Epoch 6/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9241 - loss: 0.1960 - val_accuracy: 0.5088 - val_loss: 2.7256 - learning_rate: 0.0080
# Epoch 7/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9301 - loss: 0.1811 - val_accuracy: 0.2608 - val_loss: 15.2258 - learning_rate: 0.0080
# Epoch 8/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9393 - loss: 0.1616 - val_accuracy: 0.7821 - val_loss: 1.0224 - learning_rate: 0.0080
# Epoch 9/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9373 - loss: 0.1645 - val_accuracy: 0.4716 - val_loss: 4.2552 - learning_rate: 0.0080
# Epoch 10/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9447 - loss: 0.1447 - val_accuracy: 0.7840 - val_loss: 1.0002 - learning_rate: 0.0080
# Epoch 11/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9464 - loss: 0.1397 - val_accuracy: 0.6252 - val_loss: 2.8172 - learning_rate: 0.0080
# Epoch 12/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9508 - loss: 0.1291 - val_accuracy: 0.8843 - val_loss: 0.3710 - learning_rate: 0.0080
# Epoch 13/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9519 - loss: 0.1268 - val_accuracy: 0.7199 - val_loss: 1.1902 - learning_rate: 0.0080
# Epoch 14/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9568 - loss: 0.1154 - val_accuracy: 0.8622 - val_loss: 0.4625 - learning_rate: 0.0080
# Epoch 15/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9565 - loss: 0.1161 - val_accuracy: 0.9226 - val_loss: 0.2324 - learning_rate: 0.0080
# Epoch 16/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9615 - loss: 0.1032 - val_accuracy: 0.7965 - val_loss: 0.7953 - learning_rate: 0.0080
# Epoch 17/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9627 - loss: 0.0986 - val_accuracy: 0.9132 - val_loss: 0.2695 - learning_rate: 0.0080
# Epoch 18/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9651 - loss: 0.0938 - val_accuracy: 0.6801 - val_loss: 2.4145 - learning_rate: 0.0080
# Epoch 19/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9641 - loss: 0.0966 - val_accuracy: 0.3934 - val_loss: 6.1240 - learning_rate: 0.0080
# Epoch 20/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9667 - loss: 0.0876 - val_accuracy: 0.8895 - val_loss: 0.4488 - learning_rate: 0.0080
# Epoch 21/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9680 - loss: 0.0854 - val_accuracy: 0.8754 - val_loss: 0.4087 - learning_rate: 0.0080
# Epoch 22/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9666 - loss: 0.0891 - val_accuracy: 0.4927 - val_loss: 3.8849 - learning_rate: 0.0080
# Epoch 23/300
# 284/287 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9701 - loss: 0.0774
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9709 - loss: 0.0773 - val_accuracy: 0.9192 - val_loss: 0.2930 - learning_rate: 0.0080
# Epoch 24/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9832 - loss: 0.0446 - val_accuracy: 0.9391 - val_loss: 0.2109 - learning_rate: 0.0040
# Epoch 25/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9845 - loss: 0.0416 - val_accuracy: 0.9524 - val_loss: 0.1357 - learning_rate: 0.0040
# Epoch 26/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9861 - loss: 0.0371 - val_accuracy: 0.9448 - val_loss: 0.1875 - learning_rate: 0.0040
# Epoch 27/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9854 - loss: 0.0380 - val_accuracy: 0.9246 - val_loss: 0.2858 - learning_rate: 0.0040
# Epoch 28/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9853 - loss: 0.0388 - val_accuracy: 0.9257 - val_loss: 0.2913 - learning_rate: 0.0040
# Epoch 29/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9870 - loss: 0.0355 - val_accuracy: 0.8321 - val_loss: 0.7927 - learning_rate: 0.0040
# Epoch 30/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9862 - loss: 0.0365 - val_accuracy: 0.9278 - val_loss: 0.2902 - learning_rate: 0.0040
# Epoch 31/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9850 - loss: 0.0399 - val_accuracy: 0.8658 - val_loss: 0.6523 - learning_rate: 0.0040
# Epoch 32/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9860 - loss: 0.0372 - val_accuracy: 0.9014 - val_loss: 0.4562 - learning_rate: 0.0040
# Epoch 33/300
# 284/287 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9884 - loss: 0.0299
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9867 - loss: 0.0342 - val_accuracy: 0.7479 - val_loss: 1.4616 - learning_rate: 0.0040
# Epoch 34/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9931 - loss: 0.0190 - val_accuracy: 0.9722 - val_loss: 0.0943 - learning_rate: 0.0020
# Epoch 35/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9934 - loss: 0.0173 - val_accuracy: 0.9623 - val_loss: 0.1443 - learning_rate: 0.0020
# Epoch 36/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9943 - loss: 0.0155 - val_accuracy: 0.9735 - val_loss: 0.0864 - learning_rate: 0.0020
# Epoch 37/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9935 - loss: 0.0163 - val_accuracy: 0.9688 - val_loss: 0.1139 - learning_rate: 0.0020
# Epoch 38/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9944 - loss: 0.0150 - val_accuracy: 0.9275 - val_loss: 0.3231 - learning_rate: 0.0020
# Epoch 39/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9938 - loss: 0.0164 - val_accuracy: 0.9717 - val_loss: 0.1086 - learning_rate: 0.0020
# Epoch 40/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9937 - loss: 0.0166 - val_accuracy: 0.9573 - val_loss: 0.1724 - learning_rate: 0.0020
# Epoch 41/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9945 - loss: 0.0149 - val_accuracy: 0.9479 - val_loss: 0.2477 - learning_rate: 0.0020
# Epoch 42/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9936 - loss: 0.0171 - val_accuracy: 0.9680 - val_loss: 0.1374 - learning_rate: 0.0020
# Epoch 43/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9938 - loss: 0.0154 - val_accuracy: 0.9719 - val_loss: 0.1145 - learning_rate: 0.0020
# Epoch 44/300
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9942 - loss: 0.0159
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9938 - loss: 0.0162 - val_accuracy: 0.9540 - val_loss: 0.1715 - learning_rate: 0.0020
# Epoch 45/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9962 - loss: 0.0097 - val_accuracy: 0.9680 - val_loss: 0.1463 - learning_rate: 0.0010
# Epoch 46/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9965 - loss: 0.0092 - val_accuracy: 0.9741 - val_loss: 0.1137 - learning_rate: 0.0010
# Epoch 47/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9970 - loss: 0.0076 - val_accuracy: 0.9703 - val_loss: 0.1193 - learning_rate: 0.0010
# Epoch 48/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9966 - loss: 0.0087 - val_accuracy: 0.9749 - val_loss: 0.1007 - learning_rate: 0.0010
# Epoch 49/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9970 - loss: 0.0079 - val_accuracy: 0.9727 - val_loss: 0.1125 - learning_rate: 0.0010
# Epoch 50/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9965 - loss: 0.0089 - val_accuracy: 0.9750 - val_loss: 0.1062 - learning_rate: 0.0010
# Epoch 51/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9966 - loss: 0.0079 - val_accuracy: 0.9667 - val_loss: 0.1388 - learning_rate: 0.0010
#
# Fold 1 Accuracy : 97.3524%
#                 precision    recall  f1-score   support
#
#         Asthma       0.94      0.95      0.94      1200
# Bronchiectasis       1.00      1.00      1.00      1200
#  Bronchiolitis       0.99      1.00      0.99      1200
#           COPD       0.97      0.97      0.97      1978
#        Healthy       0.95      0.92      0.94      1200
#      Pneumonia       0.98      0.98      0.98      1200
#           URTI       1.00      0.99      0.99      1200
#
#       accuracy                           0.97      9178
#      macro avg       0.97      0.97      0.97      9178
#   weighted avg       0.97      0.97      0.97      9178
# Fold 1 weights saved.
#
# ============================================
#   FOLD 2 / 5  [D1_D2_D3_Combined]
# ============================================
# Epoch 1/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.6901 - loss: 0.7927 - val_accuracy: 0.3000 - val_loss: 2.9840 - learning_rate: 0.0080
# Epoch 2/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8426 - loss: 0.4054 - val_accuracy: 0.6834 - val_loss: 1.3398 - learning_rate: 0.0080
# Epoch 3/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8822 - loss: 0.3004 - val_accuracy: 0.4449 - val_loss: 4.1044 - learning_rate: 0.0080
# Epoch 4/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9002 - loss: 0.2542 - val_accuracy: 0.6409 - val_loss: 1.7094 - learning_rate: 0.0080
# Epoch 5/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9144 - loss: 0.2207 - val_accuracy: 0.5996 - val_loss: 1.7135 - learning_rate: 0.0080
# Epoch 6/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9229 - loss: 0.1967 - val_accuracy: 0.7474 - val_loss: 1.0858 - learning_rate: 0.0080
# Epoch 7/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9291 - loss: 0.1810 - val_accuracy: 0.6581 - val_loss: 3.5003 - learning_rate: 0.0080
# Epoch 8/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9339 - loss: 0.1693 - val_accuracy: 0.6585 - val_loss: 1.9767 - learning_rate: 0.0080
# Epoch 9/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9396 - loss: 0.1574 - val_accuracy: 0.7793 - val_loss: 0.8779 - learning_rate: 0.0080
# Epoch 10/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9445 - loss: 0.1478 - val_accuracy: 0.7394 - val_loss: 1.2706 - learning_rate: 0.0080
# Epoch 11/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9463 - loss: 0.1416 - val_accuracy: 0.8932 - val_loss: 0.2967 - learning_rate: 0.0080
# Epoch 12/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9503 - loss: 0.1294 - val_accuracy: 0.9287 - val_loss: 0.1682 - learning_rate: 0.0080
# Epoch 13/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9496 - loss: 0.1310 - val_accuracy: 0.7703 - val_loss: 1.0346 - learning_rate: 0.0080
# Epoch 14/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9547 - loss: 0.1207 - val_accuracy: 0.9231 - val_loss: 0.2275 - learning_rate: 0.0080
# Epoch 15/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9570 - loss: 0.1136 - val_accuracy: 0.4505 - val_loss: 4.8624 - learning_rate: 0.0080
# Epoch 16/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9575 - loss: 0.1133 - val_accuracy: 0.3453 - val_loss: 6.4367 - learning_rate: 0.0080
# Epoch 17/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9615 - loss: 0.1038 - val_accuracy: 0.8219 - val_loss: 0.8275 - learning_rate: 0.0080
# Epoch 18/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9631 - loss: 0.0970 - val_accuracy: 0.4368 - val_loss: 4.2196 - learning_rate: 0.0080
# Epoch 19/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9626 - loss: 0.0986 - val_accuracy: 0.7870 - val_loss: 1.6003 - learning_rate: 0.0080
# Epoch 20/300
# 284/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9656 - loss: 0.0935
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9634 - loss: 0.0982 - val_accuracy: 0.5930 - val_loss: 1.9141 - learning_rate: 0.0080
# Epoch 21/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9785 - loss: 0.0587 - val_accuracy: 0.9470 - val_loss: 0.1508 - learning_rate: 0.0040
# Epoch 22/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9809 - loss: 0.0508 - val_accuracy: 0.8760 - val_loss: 0.4542 - learning_rate: 0.0040
# Epoch 23/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9828 - loss: 0.0463 - val_accuracy: 0.9433 - val_loss: 0.1620 - learning_rate: 0.0040
# Epoch 24/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9823 - loss: 0.0461 - val_accuracy: 0.9342 - val_loss: 0.2060 - learning_rate: 0.0040
# Epoch 25/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9834 - loss: 0.0452 - val_accuracy: 0.7501 - val_loss: 1.2424 - learning_rate: 0.0040
# Epoch 26/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9837 - loss: 0.0448 - val_accuracy: 0.8733 - val_loss: 0.5379 - learning_rate: 0.0040
# Epoch 27/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9843 - loss: 0.0428 - val_accuracy: 0.7985 - val_loss: 0.8870 - learning_rate: 0.0040
# Epoch 28/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9829 - loss: 0.0463 - val_accuracy: 0.9145 - val_loss: 0.3195 - learning_rate: 0.0040
# Epoch 29/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9838 - loss: 0.0427 - val_accuracy: 0.9647 - val_loss: 0.1115 - learning_rate: 0.0040
# Epoch 30/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9836 - loss: 0.0435 - val_accuracy: 0.9511 - val_loss: 0.1612 - learning_rate: 0.0040
# Epoch 31/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9848 - loss: 0.0414 - val_accuracy: 0.9352 - val_loss: 0.2338 - learning_rate: 0.0040
# Epoch 32/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9851 - loss: 0.0403 - val_accuracy: 0.9462 - val_loss: 0.1870 - learning_rate: 0.0040
# Epoch 33/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9853 - loss: 0.0385 - val_accuracy: 0.8886 - val_loss: 0.4314 - learning_rate: 0.0040
# Epoch 34/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9868 - loss: 0.0361 - val_accuracy: 0.8383 - val_loss: 0.7149 - learning_rate: 0.0040
# Epoch 35/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9850 - loss: 0.0401 - val_accuracy: 0.7596 - val_loss: 1.2129 - learning_rate: 0.0040
# Epoch 36/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9865 - loss: 0.0347 - val_accuracy: 0.9352 - val_loss: 0.2647 - learning_rate: 0.0040
# Epoch 37/300
# 285/287 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9875 - loss: 0.0332
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9870 - loss: 0.0348 - val_accuracy: 0.7756 - val_loss: 1.5225 - learning_rate: 0.0040
# Epoch 38/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9915 - loss: 0.0226 - val_accuracy: 0.9622 - val_loss: 0.1292 - learning_rate: 0.0020
# Epoch 39/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9940 - loss: 0.0166 - val_accuracy: 0.9457 - val_loss: 0.2172 - learning_rate: 0.0020
# Epoch 40/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9937 - loss: 0.0161 - val_accuracy: 0.9748 - val_loss: 0.0800 - learning_rate: 0.0020
# Epoch 41/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9933 - loss: 0.0174 - val_accuracy: 0.9687 - val_loss: 0.1170 - learning_rate: 0.0020
# Epoch 42/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9933 - loss: 0.0170 - val_accuracy: 0.9493 - val_loss: 0.1959 - learning_rate: 0.0020
# Epoch 43/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9934 - loss: 0.0176 - val_accuracy: 0.9141 - val_loss: 0.3790 - learning_rate: 0.0020
# Epoch 44/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9943 - loss: 0.0157 - val_accuracy: 0.9180 - val_loss: 0.3716 - learning_rate: 0.0020
# Epoch 45/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9932 - loss: 0.0166 - val_accuracy: 0.9667 - val_loss: 0.1193 - learning_rate: 0.0020
# Epoch 46/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9936 - loss: 0.0169 - val_accuracy: 0.9681 - val_loss: 0.1183 - learning_rate: 0.0020
# Epoch 47/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9939 - loss: 0.0169 - val_accuracy: 0.9660 - val_loss: 0.1166 - learning_rate: 0.0020
# Epoch 48/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9942 - loss: 0.0164 - val_accuracy: 0.9776 - val_loss: 0.0765 - learning_rate: 0.0020
# Epoch 49/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9949 - loss: 0.0141 - val_accuracy: 0.9670 - val_loss: 0.1278 - learning_rate: 0.0020
# Epoch 50/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9931 - loss: 0.0178 - val_accuracy: 0.9753 - val_loss: 0.0898 - learning_rate: 0.0020
# Epoch 51/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9932 - loss: 0.0168 - val_accuracy: 0.9259 - val_loss: 0.3125 - learning_rate: 0.0020
# Epoch 52/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9940 - loss: 0.0159 - val_accuracy: 0.9651 - val_loss: 0.1431 - learning_rate: 0.0020
# Epoch 53/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9945 - loss: 0.0140 - val_accuracy: 0.9635 - val_loss: 0.1577 - learning_rate: 0.0020
# Epoch 54/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9948 - loss: 0.0145 - val_accuracy: 0.9425 - val_loss: 0.2472 - learning_rate: 0.0020
# Epoch 55/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9950 - loss: 0.0132 - val_accuracy: 0.9663 - val_loss: 0.1367 - learning_rate: 0.0020
# Epoch 56/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9953 - loss: 0.0116
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9947 - loss: 0.0137 - val_accuracy: 0.9744 - val_loss: 0.0957 - learning_rate: 0.0020
# Epoch 57/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9959 - loss: 0.0098 - val_accuracy: 0.9780 - val_loss: 0.0877 - learning_rate: 0.0010
# Epoch 58/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9966 - loss: 0.0080 - val_accuracy: 0.9794 - val_loss: 0.0755 - learning_rate: 0.0010
# Epoch 59/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9971 - loss: 0.0073 - val_accuracy: 0.9780 - val_loss: 0.0862 - learning_rate: 0.0010
# Epoch 60/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9972 - loss: 0.0073 - val_accuracy: 0.9797 - val_loss: 0.0733 - learning_rate: 0.0010
# Epoch 61/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9976 - loss: 0.0060 - val_accuracy: 0.9801 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 62/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9970 - loss: 0.0077 - val_accuracy: 0.9776 - val_loss: 0.0946 - learning_rate: 0.0010
# Epoch 63/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9966 - loss: 0.0085 - val_accuracy: 0.9749 - val_loss: 0.1030 - learning_rate: 0.0010
# Epoch 64/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9969 - loss: 0.0082 - val_accuracy: 0.9785 - val_loss: 0.0871 - learning_rate: 0.0010
# Epoch 65/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9974 - loss: 0.0070 - val_accuracy: 0.9314 - val_loss: 0.3754 - learning_rate: 0.0010
# Epoch 66/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9974 - loss: 0.0072 - val_accuracy: 0.9783 - val_loss: 0.0832 - learning_rate: 0.0010
# Epoch 67/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9961 - loss: 0.0091 - val_accuracy: 0.9701 - val_loss: 0.1239 - learning_rate: 0.0010
# Epoch 68/300
# 285/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9972 - loss: 0.0072
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9967 - loss: 0.0082 - val_accuracy: 0.9722 - val_loss: 0.1220 - learning_rate: 0.0010
# Epoch 69/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9973 - loss: 0.0064 - val_accuracy: 0.9758 - val_loss: 0.1033 - learning_rate: 5.0000e-04
# Epoch 70/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9972 - loss: 0.0067 - val_accuracy: 0.9781 - val_loss: 0.0912 - learning_rate: 5.0000e-04
# Epoch 71/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9978 - loss: 0.0055 - val_accuracy: 0.9804 - val_loss: 0.0843 - learning_rate: 5.0000e-04
# Epoch 72/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9976 - loss: 0.0056 - val_accuracy: 0.9765 - val_loss: 0.1022 - learning_rate: 5.0000e-04
# Epoch 73/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9976 - loss: 0.0054 - val_accuracy: 0.9810 - val_loss: 0.0823 - learning_rate: 5.0000e-04
# Epoch 74/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9979 - loss: 0.0052 - val_accuracy: 0.9808 - val_loss: 0.0802 - learning_rate: 5.0000e-04
# Epoch 75/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9976 - loss: 0.0055 - val_accuracy: 0.9800 - val_loss: 0.0854 - learning_rate: 5.0000e-04
#
# Fold 2 Accuracy : 97.9734%
#                 precision    recall  f1-score   support
#
#         Asthma       0.97      0.94      0.96      1200
# Bronchiectasis       1.00      1.00      1.00      1200
#  Bronchiolitis       1.00      1.00      1.00      1200
#           COPD       0.98      0.99      0.98      1978
#        Healthy       0.95      0.94      0.94      1200
#      Pneumonia       0.99      0.98      0.99      1200
#           URTI       0.99      1.00      0.99      1200
#
#       accuracy                           0.98      9178
#      macro avg       0.98      0.98      0.98      9178
#   weighted avg       0.98      0.98      0.98      9178
# Fold 2 weights saved.
#
# ============================================
#   FOLD 3 / 5  [D1_D2_D3_Combined]
# ============================================
# Epoch 1/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 35s 54ms/step - accuracy: 0.6978 - loss: 0.7730 - val_accuracy: 0.4623 - val_loss: 1.7725 - learning_rate: 0.0080
# Epoch 2/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8442 - loss: 0.3963 - val_accuracy: 0.3523 - val_loss: 4.7684 - learning_rate: 0.0080
# Epoch 3/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8800 - loss: 0.3044 - val_accuracy: 0.2406 - val_loss: 16.0033 - learning_rate: 0.0080
# Epoch 4/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9006 - loss: 0.2517 - val_accuracy: 0.4627 - val_loss: 4.0995 - learning_rate: 0.0080
# Epoch 5/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9122 - loss: 0.2215 - val_accuracy: 0.3867 - val_loss: 4.3749 - learning_rate: 0.0080
# Epoch 6/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9202 - loss: 0.2024 - val_accuracy: 0.7390 - val_loss: 0.9603 - learning_rate: 0.0080
# Epoch 7/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9270 - loss: 0.1852 - val_accuracy: 0.4176 - val_loss: 3.7686 - learning_rate: 0.0080
# Epoch 8/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9335 - loss: 0.1693 - val_accuracy: 0.5040 - val_loss: 2.5280 - learning_rate: 0.0080
# Epoch 9/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9390 - loss: 0.1520 - val_accuracy: 0.7765 - val_loss: 0.8399 - learning_rate: 0.0080
# Epoch 10/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9419 - loss: 0.1514 - val_accuracy: 0.7447 - val_loss: 1.8418 - learning_rate: 0.0080
# Epoch 11/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9443 - loss: 0.1426 - val_accuracy: 0.2673 - val_loss: 14.8245 - learning_rate: 0.0080
# Epoch 12/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9451 - loss: 0.1391 - val_accuracy: 0.7349 - val_loss: 2.0871 - learning_rate: 0.0080
# Epoch 13/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9507 - loss: 0.1291 - val_accuracy: 0.3742 - val_loss: 4.5674 - learning_rate: 0.0080
# Epoch 14/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9528 - loss: 0.1223 - val_accuracy: 0.7741 - val_loss: 2.0155 - learning_rate: 0.0080
# Epoch 15/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9524 - loss: 0.1214 - val_accuracy: 0.2327 - val_loss: 20.7967 - learning_rate: 0.0080
# Epoch 16/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9564 - loss: 0.1131 - val_accuracy: 0.8831 - val_loss: 0.4250 - learning_rate: 0.0080
# Epoch 17/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9576 - loss: 0.1082 - val_accuracy: 0.8349 - val_loss: 0.7208 - learning_rate: 0.0080
# Epoch 18/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9612 - loss: 0.1022 - val_accuracy: 0.8696 - val_loss: 0.5125 - learning_rate: 0.0080
# Epoch 19/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9624 - loss: 0.0994 - val_accuracy: 0.9061 - val_loss: 0.2798 - learning_rate: 0.0080
# Epoch 20/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9636 - loss: 0.0953 - val_accuracy: 0.9040 - val_loss: 0.3270 - learning_rate: 0.0080
# Epoch 21/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9672 - loss: 0.0878 - val_accuracy: 0.7982 - val_loss: 0.9983 - learning_rate: 0.0080
# Epoch 22/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9648 - loss: 0.0923 - val_accuracy: 0.8363 - val_loss: 0.8575 - learning_rate: 0.0080
# Epoch 23/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9691 - loss: 0.0816 - val_accuracy: 0.9269 - val_loss: 0.2370 - learning_rate: 0.0080
# Epoch 24/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9685 - loss: 0.0849 - val_accuracy: 0.7352 - val_loss: 1.9684 - learning_rate: 0.0080
# Epoch 25/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9706 - loss: 0.0775 - val_accuracy: 0.9405 - val_loss: 0.1706 - learning_rate: 0.0080
# Epoch 26/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9713 - loss: 0.0791 - val_accuracy: 0.8040 - val_loss: 1.5115 - learning_rate: 0.0080
# Epoch 27/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9726 - loss: 0.0762 - val_accuracy: 0.8934 - val_loss: 0.3666 - learning_rate: 0.0080
# Epoch 28/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9724 - loss: 0.0731 - val_accuracy: 0.8592 - val_loss: 0.5839 - learning_rate: 0.0080
# Epoch 29/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9757 - loss: 0.0651 - val_accuracy: 0.5194 - val_loss: 3.8551 - learning_rate: 0.0080
# Epoch 30/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9742 - loss: 0.0718 - val_accuracy: 0.8684 - val_loss: 0.5234 - learning_rate: 0.0080
# Epoch 31/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9769 - loss: 0.0630 - val_accuracy: 0.3629 - val_loss: 8.4834 - learning_rate: 0.0080
# Epoch 32/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9751 - loss: 0.0710 - val_accuracy: 0.8842 - val_loss: 0.4748 - learning_rate: 0.0080
# Epoch 33/300
# 284/287 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9771 - loss: 0.0599
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9784 - loss: 0.0581 - val_accuracy: 0.8543 - val_loss: 0.5713 - learning_rate: 0.0080
# Epoch 34/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9873 - loss: 0.0353 - val_accuracy: 0.9438 - val_loss: 0.1938 - learning_rate: 0.0040
# Epoch 35/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9905 - loss: 0.0251 - val_accuracy: 0.9533 - val_loss: 0.1691 - learning_rate: 0.0040
# Epoch 36/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9898 - loss: 0.0275 - val_accuracy: 0.9489 - val_loss: 0.2007 - learning_rate: 0.0040
# Epoch 37/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9894 - loss: 0.0278 - val_accuracy: 0.9490 - val_loss: 0.1881 - learning_rate: 0.0040
# Epoch 38/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9893 - loss: 0.0276 - val_accuracy: 0.9631 - val_loss: 0.1214 - learning_rate: 0.0040
# Epoch 39/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9891 - loss: 0.0288 - val_accuracy: 0.9686 - val_loss: 0.1133 - learning_rate: 0.0040
# Epoch 40/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9893 - loss: 0.0276 - val_accuracy: 0.9591 - val_loss: 0.1525 - learning_rate: 0.0040
# Epoch 41/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9895 - loss: 0.0287 - val_accuracy: 0.9531 - val_loss: 0.1717 - learning_rate: 0.0040
# Epoch 42/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9902 - loss: 0.0270 - val_accuracy: 0.9719 - val_loss: 0.0919 - learning_rate: 0.0040
# Epoch 43/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9903 - loss: 0.0248 - val_accuracy: 0.8820 - val_loss: 0.5266 - learning_rate: 0.0040
# Epoch 44/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9888 - loss: 0.0300 - val_accuracy: 0.9652 - val_loss: 0.1264 - learning_rate: 0.0040
# Epoch 45/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9897 - loss: 0.0287 - val_accuracy: 0.9560 - val_loss: 0.1744 - learning_rate: 0.0040
# Epoch 46/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9912 - loss: 0.0237 - val_accuracy: 0.9498 - val_loss: 0.2083 - learning_rate: 0.0040
# Epoch 47/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.9907 - loss: 0.0258 - val_accuracy: 0.9530 - val_loss: 0.1836 - learning_rate: 0.0040
# Epoch 48/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9902 - loss: 0.0262 - val_accuracy: 0.9553 - val_loss: 0.1973 - learning_rate: 0.0040
# Epoch 49/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9901 - loss: 0.0259 - val_accuracy: 0.9401 - val_loss: 0.2772 - learning_rate: 0.0040
# Epoch 50/300
# 285/287 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9908 - loss: 0.0257
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9909 - loss: 0.0249 - val_accuracy: 0.9728 - val_loss: 0.0950 - learning_rate: 0.0040
# Epoch 51/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9953 - loss: 0.0128 - val_accuracy: 0.9710 - val_loss: 0.1192 - learning_rate: 0.0020
# Epoch 52/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9949 - loss: 0.0131 - val_accuracy: 0.9266 - val_loss: 0.2952 - learning_rate: 0.0020
# Epoch 53/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9958 - loss: 0.0112 - val_accuracy: 0.9795 - val_loss: 0.0901 - learning_rate: 0.0020
# Epoch 54/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9969 - loss: 0.0085 - val_accuracy: 0.9792 - val_loss: 0.0866 - learning_rate: 0.0020
# Epoch 55/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9960 - loss: 0.0101 - val_accuracy: 0.9280 - val_loss: 0.3793 - learning_rate: 0.0020
# Epoch 56/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9955 - loss: 0.0112 - val_accuracy: 0.9776 - val_loss: 0.0969 - learning_rate: 0.0020
# Epoch 57/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9962 - loss: 0.0106 - val_accuracy: 0.9650 - val_loss: 0.1557 - learning_rate: 0.0020
# Epoch 58/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9958 - loss: 0.0111 - val_accuracy: 0.9713 - val_loss: 0.1325 - learning_rate: 0.0020
# Epoch 59/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9959 - loss: 0.0105 - val_accuracy: 0.9734 - val_loss: 0.1116 - learning_rate: 0.0020
# Epoch 60/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9959 - loss: 0.0104 - val_accuracy: 0.9210 - val_loss: 0.3762 - learning_rate: 0.0020
# Epoch 61/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9963 - loss: 0.0098 - val_accuracy: 0.9573 - val_loss: 0.1986 - learning_rate: 0.0020
# Epoch 62/300
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9962 - loss: 0.0089
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9954 - loss: 0.0116 - val_accuracy: 0.9649 - val_loss: 0.1527 - learning_rate: 0.0020
# Epoch 63/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9968 - loss: 0.0093 - val_accuracy: 0.9796 - val_loss: 0.0963 - learning_rate: 0.0010
# Epoch 64/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9976 - loss: 0.0063 - val_accuracy: 0.9765 - val_loss: 0.1063 - learning_rate: 0.0010
# Epoch 65/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9974 - loss: 0.0064 - val_accuracy: 0.9720 - val_loss: 0.1234 - learning_rate: 0.0010
# Epoch 66/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9972 - loss: 0.0065 - val_accuracy: 0.9788 - val_loss: 0.0971 - learning_rate: 0.0010
# Epoch 67/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9975 - loss: 0.0061 - val_accuracy: 0.9789 - val_loss: 0.0920 - learning_rate: 0.0010
# Epoch 68/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9977 - loss: 0.0060 - val_accuracy: 0.9782 - val_loss: 0.1016 - learning_rate: 0.0010
# Epoch 69/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9977 - loss: 0.0059 - val_accuracy: 0.9792 - val_loss: 0.0955 - learning_rate: 0.0010
#
# Fold 3 Accuracy : 97.9189%
#                 precision    recall  f1-score   support
#
#         Asthma       0.96      0.95      0.96      1200
# Bronchiectasis       1.00      1.00      1.00      1200
#  Bronchiolitis       1.00      1.00      1.00      1200
#           COPD       0.97      0.98      0.98      1978
#        Healthy       0.95      0.94      0.94      1200
#      Pneumonia       0.98      0.99      0.99      1200
#           URTI       0.99      0.99      0.99      1200
#
#       accuracy                           0.98      9178
#      macro avg       0.98      0.98      0.98      9178
#   weighted avg       0.98      0.98      0.98      9178
# Fold 3 weights saved.
#
# ============================================
#   FOLD 4 / 5  [D1_D2_D3_Combined]
# ============================================
# Epoch 1/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 40s 73ms/step - accuracy: 0.6885 - loss: 0.8036 - val_accuracy: 0.5153 - val_loss: 1.7369 - learning_rate: 0.0080
# Epoch 2/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8415 - loss: 0.4097 - val_accuracy: 0.7619 - val_loss: 0.7487 - learning_rate: 0.0080
# Epoch 3/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8822 - loss: 0.2980 - val_accuracy: 0.5893 - val_loss: 1.7254 - learning_rate: 0.0080
# Epoch 4/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9002 - loss: 0.2527 - val_accuracy: 0.6317 - val_loss: 1.6296 - learning_rate: 0.0080
# Epoch 5/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9110 - loss: 0.2225 - val_accuracy: 0.8228 - val_loss: 0.6826 - learning_rate: 0.0080
# Epoch 6/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9219 - loss: 0.1967 - val_accuracy: 0.6746 - val_loss: 1.3337 - learning_rate: 0.0080
# Epoch 7/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9293 - loss: 0.1783 - val_accuracy: 0.8211 - val_loss: 0.5433 - learning_rate: 0.0080
# Epoch 8/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9318 - loss: 0.1725 - val_accuracy: 0.7427 - val_loss: 0.9579 - learning_rate: 0.0080
# Epoch 9/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9358 - loss: 0.1605 - val_accuracy: 0.8405 - val_loss: 0.4617 - learning_rate: 0.0080
# Epoch 10/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9411 - loss: 0.1500 - val_accuracy: 0.7507 - val_loss: 0.8905 - learning_rate: 0.0080
# Epoch 11/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9419 - loss: 0.1428 - val_accuracy: 0.5440 - val_loss: 2.8062 - learning_rate: 0.0080
# Epoch 12/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9472 - loss: 0.1351 - val_accuracy: 0.3487 - val_loss: 6.8807 - learning_rate: 0.0080
# Epoch 13/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9521 - loss: 0.1217 - val_accuracy: 0.9191 - val_loss: 0.2307 - learning_rate: 0.0080
# Epoch 14/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9525 - loss: 0.1203 - val_accuracy: 0.8059 - val_loss: 0.8408 - learning_rate: 0.0080
# Epoch 15/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9542 - loss: 0.1177 - val_accuracy: 0.8688 - val_loss: 0.4888 - learning_rate: 0.0080
# Epoch 16/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9591 - loss: 0.1056 - val_accuracy: 0.8724 - val_loss: 0.3897 - learning_rate: 0.0080
# Epoch 17/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9594 - loss: 0.1059 - val_accuracy: 0.9029 - val_loss: 0.2777 - learning_rate: 0.0080
# Epoch 18/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9631 - loss: 0.0941 - val_accuracy: 0.9015 - val_loss: 0.2973 - learning_rate: 0.0080
# Epoch 19/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9622 - loss: 0.0970 - val_accuracy: 0.8392 - val_loss: 0.6357 - learning_rate: 0.0080
# Epoch 20/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9634 - loss: 0.0955 - val_accuracy: 0.9073 - val_loss: 0.2930 - learning_rate: 0.0080
# Epoch 21/300
# 285/287 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9684 - loss: 0.0823
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9667 - loss: 0.0884 - val_accuracy: 0.8823 - val_loss: 0.4009 - learning_rate: 0.0080
# Epoch 22/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9779 - loss: 0.0572 - val_accuracy: 0.7496 - val_loss: 1.0686 - learning_rate: 0.0040
# Epoch 23/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9820 - loss: 0.0457 - val_accuracy: 0.8737 - val_loss: 0.7626 - learning_rate: 0.0040
# Epoch 24/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9828 - loss: 0.0454 - val_accuracy: 0.8583 - val_loss: 0.5276 - learning_rate: 0.0040
# Epoch 25/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9822 - loss: 0.0462 - val_accuracy: 0.9595 - val_loss: 0.1179 - learning_rate: 0.0040
# Epoch 26/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9822 - loss: 0.0455 - val_accuracy: 0.9391 - val_loss: 0.2190 - learning_rate: 0.0040
# Epoch 27/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9843 - loss: 0.0417 - val_accuracy: 0.9359 - val_loss: 0.2136 - learning_rate: 0.0040
# Epoch 28/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9850 - loss: 0.0411 - val_accuracy: 0.8187 - val_loss: 1.1677 - learning_rate: 0.0040
# Epoch 29/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9841 - loss: 0.0425 - val_accuracy: 0.9458 - val_loss: 0.1597 - learning_rate: 0.0040
# Epoch 30/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9843 - loss: 0.0396 - val_accuracy: 0.9247 - val_loss: 0.2508 - learning_rate: 0.0040
# Epoch 31/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9867 - loss: 0.0365 - val_accuracy: 0.9566 - val_loss: 0.1376 - learning_rate: 0.0040
# Epoch 32/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9858 - loss: 0.0381 - val_accuracy: 0.9441 - val_loss: 0.1845 - learning_rate: 0.0040
# Epoch 33/300
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9865 - loss: 0.0373
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9847 - loss: 0.0398 - val_accuracy: 0.9114 - val_loss: 0.2938 - learning_rate: 0.0040
# Epoch 34/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9920 - loss: 0.0217 - val_accuracy: 0.9782 - val_loss: 0.0714 - learning_rate: 0.0020
# Epoch 35/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9928 - loss: 0.0186 - val_accuracy: 0.9764 - val_loss: 0.0798 - learning_rate: 0.0020
# Epoch 36/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9928 - loss: 0.0176 - val_accuracy: 0.9759 - val_loss: 0.0821 - learning_rate: 0.0020
# Epoch 37/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9933 - loss: 0.0179 - val_accuracy: 0.9643 - val_loss: 0.1412 - learning_rate: 0.0020
# Epoch 38/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9939 - loss: 0.0164 - val_accuracy: 0.9786 - val_loss: 0.0707 - learning_rate: 0.0020
# Epoch 39/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9939 - loss: 0.0155 - val_accuracy: 0.9767 - val_loss: 0.0770 - learning_rate: 0.0020
# Epoch 40/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9931 - loss: 0.0182 - val_accuracy: 0.9723 - val_loss: 0.1013 - learning_rate: 0.0020
# Epoch 41/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9934 - loss: 0.0171 - val_accuracy: 0.9771 - val_loss: 0.0814 - learning_rate: 0.0020
# Epoch 42/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9943 - loss: 0.0152 - val_accuracy: 0.9719 - val_loss: 0.0959 - learning_rate: 0.0020
# Epoch 43/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9937 - loss: 0.0164 - val_accuracy: 0.9765 - val_loss: 0.0882 - learning_rate: 0.0020
# Epoch 44/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9937 - loss: 0.0166 - val_accuracy: 0.9736 - val_loss: 0.0998 - learning_rate: 0.0020
# Epoch 45/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9938 - loss: 0.0159 - val_accuracy: 0.9563 - val_loss: 0.2030 - learning_rate: 0.0020
# Epoch 46/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9942 - loss: 0.0160
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9940 - loss: 0.0164 - val_accuracy: 0.9061 - val_loss: 0.3534 - learning_rate: 0.0020
# Epoch 47/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9952 - loss: 0.0116 - val_accuracy: 0.9798 - val_loss: 0.0787 - learning_rate: 0.0010
# Epoch 48/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9965 - loss: 0.0091 - val_accuracy: 0.9722 - val_loss: 0.0987 - learning_rate: 0.0010
# Epoch 49/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9967 - loss: 0.0087 - val_accuracy: 0.9658 - val_loss: 0.1441 - learning_rate: 0.0010
# Epoch 50/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9972 - loss: 0.0075 - val_accuracy: 0.9786 - val_loss: 0.0879 - learning_rate: 0.0010
# Epoch 51/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9969 - loss: 0.0079 - val_accuracy: 0.9791 - val_loss: 0.0749 - learning_rate: 0.0010
# Epoch 52/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9966 - loss: 0.0089 - val_accuracy: 0.9659 - val_loss: 0.1516 - learning_rate: 0.0010
# Epoch 53/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9971 - loss: 0.0076 - val_accuracy: 0.9750 - val_loss: 0.0958 - learning_rate: 0.0010
#
# Fold 4 Accuracy : 97.8642%
#                 precision    recall  f1-score   support
#
#         Asthma       0.97      0.93      0.95      1200
# Bronchiectasis       1.00      1.00      1.00      1200
#  Bronchiolitis       1.00      1.00      1.00      1200
#           COPD       0.98      0.98      0.98      1977
#        Healthy       0.93      0.95      0.94      1200
#      Pneumonia       0.98      0.99      0.99      1200
#           URTI       1.00      0.99      0.99      1200
#
#       accuracy                           0.98      9177
#      macro avg       0.98      0.98      0.98      9177
#   weighted avg       0.98      0.98      0.98      9177
# Fold 4 weights saved.
#
# ============================================
#   FOLD 5 / 5  [D1_D2_D3_Combined]
# ============================================
# Epoch 1/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.6962 - loss: 0.7812 - val_accuracy: 0.4024 - val_loss: 2.9534 - learning_rate: 0.0080
# Epoch 2/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8467 - loss: 0.3873 - val_accuracy: 0.6630 - val_loss: 1.2214 - learning_rate: 0.0080
# Epoch 3/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.8844 - loss: 0.2907 - val_accuracy: 0.8544 - val_loss: 0.4359 - learning_rate: 0.0080
# Epoch 4/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9039 - loss: 0.2469 - val_accuracy: 0.6113 - val_loss: 1.7731 - learning_rate: 0.0080
# Epoch 5/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9162 - loss: 0.2145 - val_accuracy: 0.2464 - val_loss: 11.5440 - learning_rate: 0.0080
# Epoch 6/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9242 - loss: 0.1925 - val_accuracy: 0.7275 - val_loss: 0.9097 - learning_rate: 0.0080
# Epoch 7/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9302 - loss: 0.1793 - val_accuracy: 0.8222 - val_loss: 0.6011 - learning_rate: 0.0080
# Epoch 8/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9354 - loss: 0.1653 - val_accuracy: 0.7352 - val_loss: 1.2642 - learning_rate: 0.0080
# Epoch 9/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9370 - loss: 0.1601 - val_accuracy: 0.4632 - val_loss: 3.6750 - learning_rate: 0.0080
# Epoch 10/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9450 - loss: 0.1432 - val_accuracy: 0.7645 - val_loss: 0.9255 - learning_rate: 0.0080
# Epoch 11/300
# 284/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9458 - loss: 0.1383
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9447 - loss: 0.1435 - val_accuracy: 0.7897 - val_loss: 0.8172 - learning_rate: 0.0080
# Epoch 12/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9649 - loss: 0.0907 - val_accuracy: 0.8732 - val_loss: 0.3769 - learning_rate: 0.0040
# Epoch 13/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9678 - loss: 0.0839 - val_accuracy: 0.9029 - val_loss: 0.2886 - learning_rate: 0.0040
# Epoch 14/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9705 - loss: 0.0755 - val_accuracy: 0.9320 - val_loss: 0.2124 - learning_rate: 0.0040
# Epoch 15/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9718 - loss: 0.0729 - val_accuracy: 0.9266 - val_loss: 0.2152 - learning_rate: 0.0040
# Epoch 16/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9716 - loss: 0.0752 - val_accuracy: 0.9546 - val_loss: 0.1286 - learning_rate: 0.0040
# Epoch 17/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9744 - loss: 0.0674 - val_accuracy: 0.9563 - val_loss: 0.1313 - learning_rate: 0.0040
# Epoch 18/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9739 - loss: 0.0675 - val_accuracy: 0.9188 - val_loss: 0.2573 - learning_rate: 0.0040
# Epoch 19/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9759 - loss: 0.0635 - val_accuracy: 0.8790 - val_loss: 0.4254 - learning_rate: 0.0040
# Epoch 20/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9764 - loss: 0.0618 - val_accuracy: 0.9577 - val_loss: 0.1172 - learning_rate: 0.0040
# Epoch 21/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9771 - loss: 0.0599 - val_accuracy: 0.9436 - val_loss: 0.1875 - learning_rate: 0.0040
# Epoch 22/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9785 - loss: 0.0562 - val_accuracy: 0.7616 - val_loss: 1.1897 - learning_rate: 0.0040
# Epoch 23/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9798 - loss: 0.0521 - val_accuracy: 0.8643 - val_loss: 0.6672 - learning_rate: 0.0040
# Epoch 24/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9789 - loss: 0.0551 - val_accuracy: 0.8665 - val_loss: 0.4609 - learning_rate: 0.0040
# Epoch 25/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9801 - loss: 0.0517 - val_accuracy: 0.9495 - val_loss: 0.1572 - learning_rate: 0.0040
# Epoch 26/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9812 - loss: 0.0511 - val_accuracy: 0.9284 - val_loss: 0.2212 - learning_rate: 0.0040
# Epoch 27/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9825 - loss: 0.0469 - val_accuracy: 0.8421 - val_loss: 0.8004 - learning_rate: 0.0040
# Epoch 28/300
# 286/287 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9816 - loss: 0.0488
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9832 - loss: 0.0455 - val_accuracy: 0.4882 - val_loss: 4.5513 - learning_rate: 0.0040
# Epoch 29/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9906 - loss: 0.0255 - val_accuracy: 0.9723 - val_loss: 0.0899 - learning_rate: 0.0020
# Epoch 30/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9913 - loss: 0.0218 - val_accuracy: 0.9703 - val_loss: 0.0943 - learning_rate: 0.0020
# Epoch 31/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9917 - loss: 0.0219 - val_accuracy: 0.9706 - val_loss: 0.0983 - learning_rate: 0.0020
# Epoch 32/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9926 - loss: 0.0198 - val_accuracy: 0.9699 - val_loss: 0.1084 - learning_rate: 0.0020
# Epoch 33/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9916 - loss: 0.0214 - val_accuracy: 0.9673 - val_loss: 0.1148 - learning_rate: 0.0020
# Epoch 34/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9904 - loss: 0.0252 - val_accuracy: 0.9549 - val_loss: 0.1634 - learning_rate: 0.0020
# Epoch 35/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9922 - loss: 0.0206 - val_accuracy: 0.9660 - val_loss: 0.1201 - learning_rate: 0.0020
# Epoch 36/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9910 - loss: 0.0238 - val_accuracy: 0.9556 - val_loss: 0.1837 - learning_rate: 0.0020
# Epoch 37/300
# 286/287 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9943 - loss: 0.0145
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9938 - loss: 0.0166 - val_accuracy: 0.9601 - val_loss: 0.1316 - learning_rate: 0.0020
# Epoch 38/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9956 - loss: 0.0126 - val_accuracy: 0.9759 - val_loss: 0.0807 - learning_rate: 0.0010
# Epoch 39/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9953 - loss: 0.0124 - val_accuracy: 0.9688 - val_loss: 0.1064 - learning_rate: 0.0010
# Epoch 40/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9958 - loss: 0.0107 - val_accuracy: 0.9765 - val_loss: 0.0857 - learning_rate: 0.0010
# Epoch 41/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9956 - loss: 0.0110 - val_accuracy: 0.9780 - val_loss: 0.0845 - learning_rate: 0.0010
# Epoch 42/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9962 - loss: 0.0094 - val_accuracy: 0.9778 - val_loss: 0.0866 - learning_rate: 0.0010
# Epoch 43/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9961 - loss: 0.0092 - val_accuracy: 0.9682 - val_loss: 0.1318 - learning_rate: 0.0010
# Epoch 44/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9964 - loss: 0.0100 - val_accuracy: 0.9764 - val_loss: 0.0970 - learning_rate: 0.0010
# Epoch 45/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9966 - loss: 0.0097 - val_accuracy: 0.9750 - val_loss: 0.0987 - learning_rate: 0.0010
# Epoch 46/300
# 283/287 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9956 - loss: 0.0113
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9956 - loss: 0.0112 - val_accuracy: 0.9752 - val_loss: 0.1024 - learning_rate: 0.0010
# Epoch 47/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9966 - loss: 0.0084 - val_accuracy: 0.9768 - val_loss: 0.0895 - learning_rate: 5.0000e-04
# Epoch 48/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9974 - loss: 0.0068 - val_accuracy: 0.9700 - val_loss: 0.1240 - learning_rate: 5.0000e-04
# Epoch 49/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9972 - loss: 0.0068 - val_accuracy: 0.9769 - val_loss: 0.0975 - learning_rate: 5.0000e-04
# Epoch 50/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9781 - val_loss: 0.0868 - learning_rate: 5.0000e-04
# Epoch 51/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9971 - loss: 0.0068 - val_accuracy: 0.9741 - val_loss: 0.1132 - learning_rate: 5.0000e-04
# Epoch 52/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9975 - loss: 0.0062 - val_accuracy: 0.9778 - val_loss: 0.0959 - learning_rate: 5.0000e-04
# Epoch 53/300
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9975 - loss: 0.0064 - val_accuracy: 0.9744 - val_loss: 0.0978 - learning_rate: 5.0000e-04
#
# Fold 5 Accuracy : 97.5918%
#                 precision    recall  f1-score   support
#
#         Asthma       0.96      0.93      0.95      1200
# Bronchiectasis       1.00      1.00      1.00      1200
#  Bronchiolitis       0.99      1.00      1.00      1200
#           COPD       0.98      0.98      0.98      1977
#        Healthy       0.92      0.94      0.93      1200
#      Pneumonia       0.98      0.99      0.98      1200
#           URTI       0.99      0.99      0.99      1200
#
#       accuracy                           0.98      9177
#      macro avg       0.98      0.98      0.98      9177
#   weighted avg       0.98      0.98      0.98      9177
# Fold 5 weights saved.
#
# ============================================
# FINAL RESULTS — D1_D2_D3_Combined
# ============================================
#   Fold 1 : 97.3524%
#   Fold 2 : 97.9734%
#   Fold 3 : 97.9189%
#   Fold 4 : 97.8642%
#   Fold 5 : 97.5918%
#   Mean  : 97.7401%
#   Std   : 0.2342%
